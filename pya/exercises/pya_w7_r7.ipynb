# %% [markdown]
# # ΕΚΔΔΑ - Python-A
#
# Ονοματεπώνυμο επιμορφούμενου: [συμπληρώστε εδώ το ονομά σας]
#
# ## Εβδομάδα 7 - Εισαγωγή στον αντικειμενοστραφή προγραμματισμό

# %% [markdown]
# ### Κλάσεις και αντικείμενα
#
#
# Δημιουργήστε μια κλάση `Interval` που έχει χαρακτηριστικά τα `_from` και `_to` και αναπαριστά ένα διάστημα που ξεκινά τη χρονική στιγμή `_from` και φτάνει χωρίς να συμπεριλαμβάνει τη χρονική στιγμή `_to`. Τα χαρακτηριστικά να αρχικοποιούνται μέσω της `__init__()` της κλάσης. Ωστόσο αν επιχειρηθεί να δημιουργηθεί αντικείμενο με `_from` μεγαλύτερο ή ίσο του `_to` να προκαλείται εξαίρεση `ValueError`.
# - Προσθέστε μια μέθοδο `overlap()` που να εξετάζει αν το διάστημα για το οποίο καλείται η μέθοδος, έχει επικάλυψη με ένα διάστημα που θα δέχεται ως παράμετρο επιστρέφοντας `True` ή `False`. Δείτε σχετικά το <https://stackoverflow.com/questions/3269434/whats-the-most-efficient-way-to-test-if-two-ranges-overlap>.
# - Υλοποιήστε τη μέθοδο `__str__()` έτσι ώστε κατά την εκτύπωση κάθε αντικειμένου `Interval` να εμφανίζονται οι τιμές των χαρακτηριστικών του με τη μορφή `[_from, _to]` π.χ. `[3, 9)`, όπως δηλαδή ένα διάστημα στα μαθηματικά, κλειστό αριστερά και ανοικτό δεξιά.
# - Δημιουργήστε μια λίστα με 3 αντικείμενα `Interval` με εισαγωγή τιμών από τον χρήστη. Αν προκληθεί εξαίρεση κατά την εισαγωγή τιμών να εμφανίζει μήνυμα λάθους και να ζητείται η εισαγωγή της τιμής ξανά μέχρι να είναι αποδεκτή. Τέλος να εμφανίζονται πρώτα τα 3 διαστήματα της λίστας καθώς και όσα ζεύγη διαστημάτων έχουν επικάλυψη.
#
#
# Δείτε ένα παράδειγμα εκτέλεσης που θα παράγει ο ζητούμενος κώδικας:
# ```cmd
# Δώσε αρχή διαστήματος 1: 1
# Δωσε τέλος διαστήματος 1: 5
#
# Δώσε αρχή διαστήματος 2: 7
# Δωσε τέλος διαστήματος 2: 3
# Σφάλμα: Η αρχή του διαστήματος πρέπει να είναι μικρότερη από το τέλος.
# Παρακαλώ προσπάθησε ξανά.
# Δώσε αρχή διαστήματος 2: 3
# Δωσε τέλος διαστήματος 2: 7
#
# Δώσε αρχή διαστήματος 2: 9
# Δωσε τέλος διαστήματος 2: 12
#
# Τα διαστήματα που δόθηκαν είναι:
# [1, 5)
# [3, 7)
# [9, 12)
#
# Ζεύγη διαστημάτων με επικάλυψη:
# [1, 5) με [3, 7)
# ```

# %%
# Λύση
