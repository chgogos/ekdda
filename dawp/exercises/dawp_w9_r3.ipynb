# %% [markdown]
# # Εργαστηριακή άσκηση 9ης εβδομάδας

# %% [markdown]
# ## Εκφώνηση
#
# Χρησιμοποιήστε το σύνολο δεδομένων [Auto MPG](https://archive.ics.uci.edu/dataset/9/auto+mpg) από το <https://archive.ics.uci.edu/> για να αναπτύξετε ένα απλό μοντέλο γραμμικής παλινδρόμησης με τη βιβλιοθήκη scikit-learn. Στόχος είναι να προβλέψετε την κατανάλωση καυσίμου `mpg` (miles per gallon) με βάση ένα ή περισσότερα από τα υπόλοιπα χαρακτηριστικά του συνόλου δεδομένων.
#
# **Ερωτήματα**
# 1. Φορτώστε το σύνολο δεδομένων Auto MPG σε ένα pandas DataFrame.
# 2. Διαγράψτε όλες τις εγγραφές που έχουν στο χαρακτηριστικό εισόδου `horsepower` τιμή `ΝΑ` (κενές τιμές).
# 3. Επιλέξτε ως μεταβλητή στόχο τη στήλη `mpg` και ως χαρακτηριστικά εισόδου τις στήλες:
#    * `weight`
#    * `horsepower`
#    * `displacement`
# 4. Χωρίστε τα δεδομένα σε σύνολο εκπαίδευσης και σύνολο ελέγχου, με ποσοστό 80%–20%
# 5. Δημιουργήστε και εκπαιδεύστε ένα μοντέλο LinearRegression από το scikit-learn.
# 6. Υπολογίστε τις προβλέψεις του μοντέλου για το σύνολο ελέγχου.
# 7. Υπολογίστε και εμφανίστε τις παρακάτω μετρικές αξιολόγησης:
#    1. Mean Absolute Error (MAE)
#    2. Mean Squared Error (MSE)
#    3. Root Mean Squared Error (RMSE)
#    4. Coefficient of Determination ($R^2$)
# 8. Εμφανίστε τους συντελεστές του μοντέλου και την τιμή του σταθερού όρου.
# 9. Συγκρίνατε την απόδοση του μοντέλου με το αν είχε επιλεγεί ως χαρακτηριστικό εισόδου μόνο το `weight`

# %%
# Ερώτημα 1

# %%
# Ερώτημα 2

# %%
# Ερώτημα 3

# %%
# Ερώτημα 4

# %%
# Ερώτημα 5

# %%
# Ερώτημα 6

# %%
# Ερώτημα 7

# %%
# Ερώτημα 8

# %%
# Ερώτημα 9
