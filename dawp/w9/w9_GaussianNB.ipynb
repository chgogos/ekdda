# %% [markdown]
# # Naive Bayes classification

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(100, 2, centers=2, random_state=42, cluster_std=1.5)
colors = np.array(["red", "blue"])
plt.scatter(X[:, 0], X[:, 1], c=colors[y], s=50)
for label, c in enumerate(colors):
    plt.scatter([], [], c=c, label=str(label))
plt.legend()

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X, y);

# %%
print("Means:", model.theta_)
print("Variances:", model.var_)
# Out:
# Means: [[-2.79978571  8.82802938]
#  [ 4.59266723  2.26838804]]
# Variances: [[1.55780446 2.04307693]
#  [1.71091669 2.24400288]]

# %%
from sklearn.metrics import accuracy_score
y_fitted = model.predict(X)
acc=accuracy_score(y,y_fitted)
print("Accuracy score is", acc)
# Out:
# Accuracy score is 1.0
